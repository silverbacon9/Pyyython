# %% [markdown]
# |語法|說明|
# |:---:|:---:|
# | %s |插入  的值到字串中|
# | %d |插入  的值到字串中|
# | %d |插入  的值到字串中|
# | %% |輸出  (類似跳脫字元)|

# %%
# 多組文字
msg = "%s, %s!" % ("Hello", "world")
print(msg)

data1= "Hello"
data2 = "world"
msg = "%s,%s!" % (data1, data2)
print(msg)

# %%
# 整數
age = 18 
msg = "I am %d years old." % (age)
msg = "資料輸出的結果 AGE = %d " % (age)
print(msg)

# %%
# 文字與整數
msg = "%s is %d years old." % ("Jarvis", 18)
print(msg)
# Out:
# Jarvis is 18 years old.

# %%
# 指定寬度 (維持 10 個字元長度，預設向右看齊)
msg = "[%10s]" % "Hello"
print(msg)
# Out:
# [     Hello]

# %%
# 靠左對齊 (維持 10 個字元長度，向左對齊)
msg = "[%-10s]" % "Hello"
print(msg)

# %%
# 指定浮點數位數
msg = "%.2f %%" % 3.14256
# 如果要打出 " % " ，打 " %% "
print(msg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 指定浮點數位數
#       2 msg = "%.2f %%" % 3.14256
# ----> 3 如果要打出
#       4 print(msg)
#
# NameError: name '如果要打出' is not defined

# %%
# 指定文字長度上限 (只有文字，才在格式化字串中加入「.」來限定字串長度)
msg = "%.2s" % "Hello"
print(msg)
# Out:
# He

# %%
# 空白補 0
msg = "[%.6f]" %  3.14
print(msg)
# Out:
# [3.140000]
