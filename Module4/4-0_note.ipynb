# %% [markdown]
# |型態| 創建方式 | 可不可變 | 有序/無序 |
# |:---:|:---:|:---:|:---:|
# |list| ids = [1, 2, 3] | V | V |
# |dict| info = {"name", 2, 3} | V | X |
# |tuple| ids = (1, 2, 3) | X | V |
# |set| name = "Jarvis" | X | V |
# |str| name = "Jarvis" | X | V |

# %%
# 字串整數初始化
name = "Jarvis"
print(name)
print(name[0])
# Out:
# Jarvis
# J
