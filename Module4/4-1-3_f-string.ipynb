# %%
# f-string (又稱作 formatted string literals, version >= 3.6)
name = "Jarvis"
age = 18
print(f"{name} is {age} yeaers old! ")
# Out:
# Jarvis is 18 yeaers old!

# %%
now = "2025-11-01 15:32"
status = "INFO"
log = f"{now} [{status}] - {msg}"
print(log)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 msg = "2025-11-01 15:32"
#       2 status = "INFO"
# ----> 3 log = f"{now} [{status}] - {msg}"
#       4 print(log)
#
# NameError: name 'now' is not defined

# %%
# 靠左對齊、靠右對齊
name = "Jarvis"
age = 18
msg = f"name: [{name:<10}], age:[{age:>10}]"
print(msg)
# Out:
# name: [Jarvis    ], age:[        18]

# %%
# 靠左對齊、靠右對齊，字數不足，補「ㄏ」
# (沒寫補什麼，預設空格)
name = "Jarvis"
age = 18
msg = f"name: [{name:ㄏ<10}], age:[{age:ㄏ>10}]"
print(msg)
# Out:
# name: [Jarvisㄏㄏㄏㄏ], age:[ㄏㄏㄏㄏㄏㄏㄏㄏ18]

# %%
# 置中對齊
name = "Jarvis"
age = 18
msg = f"name: [{name:^10}], age:[{age:^10}]"
print(msg)
# Out:
# name: [  Jarvis  ], age:[    18    ]

# %%
# 指定文字長度上限 (只有文字，才在格式化字串中加入「.」來限定字串長度)
name = "Jarvis"

msg = f"name: [{name:.2}]"
print(msg)
# Out:
# name: [Ja]

# %%
data = 3.145671475415
print(f"{data:.2f}")
# Out:
# 3.15
