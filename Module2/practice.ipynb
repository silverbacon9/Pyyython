# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
# shopping = input("請輸入您的消費總金額是:")
# if int(shopping) > 2000 :
#     total = int(shopping) - 200
# print("折扣後的金額為", total, "元")

total = 5500
if total >= 2000:
    total -= 200 
print(total)
# Out:
# 折扣後的金額為 4800 元

# %%
# 滿 4000 折 400
# 滿 6000 折 600

# %%
# shopping2 = int(input("請輸入您今日的消費金額是:"))
# if shopping2 > 4000 and shopping2 < 6000 :
#     shopping2 -= 400
# elif shopping2 > 6000 :
#     shopping2 -= 600

# print("折扣後的金額為: ", shopping2, "元")

total = 6500
discount = 200
if total >= 2000:
    #cnt = total // 2000
    # total -= discount * cnt
    total -= discount * (total//2000)
print(total)
# Out:
# 折扣後的金額為:  5800 元
